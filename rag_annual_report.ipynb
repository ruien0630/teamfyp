# %%
import docling_util_baseline as docling_util

# %%
## Process only the 3 CBA PDFs to markdown ##
## CHECK THAT YOU HAVE THE PDF FILES IN INPUT folder

docling_util.process_documents_to_md("input", "no image annotation")
docling_util.process_markdown_folder('output_md') # process_markdown_folder always dump to 'outputs' folder.")
# Out:
# .pdf files found:
#   - CBA - Annual Report 2021.pdf
#   - CBA - Annual Report 2022.pdf
#
# Total files to process: 2
# Using 7 parallel workers
# Processing documents:  50%|█████     | 1/2 [31:56<31:56, 1916.22s/it]
# ✓ Processed: CBA - Annual Report 2022.pdf
# Processing documents: 100%|██████████| 2/2 [35:15<00:00, 1057.75s/it]
# ✓ Processed: CBA - Annual Report 2021.pdf
# Processing complete!
# ✓ Successfully processed: 2 files
# Processing markdown files in folder: output_md
#
# Processing md file: output_md\CBA - Annual Report 2020.md
# Analyzing image filename: output_md\output_md\CBA - Annual Report 2020_artifacts\image_000000_20e25d3ea85d8e67ce5dc3416c1e874d08b1605815645f6fa781fa7b1a04cfd9.png
# Analyzing image filename: output_md\output_md\CBA - Annual Report 2020_artifacts\image_000001_23f208927879257976dc2d635db9c37b2f60944d06b80165b9b4f7bb3c20e247.png
# Analyzing image filename: output_md\output_md\CBA - Annual Report 2020_artifacts\image_000002_9797c42d2277b2401ae176264c58d07c2ee4ea204e0c9c0ada7f7bfade0ee1e9.png
# Analyzing image filename: output_md\output_md\CBA - Annual Report 2020_artifacts\image_000003_4d5cd76b9cefa43835db5e8f865e72fb10d819b3401170b2fb4c03af4fa9b9c5.png
# Analyzing image filename: output_md\output_md\CBA - Annual Report 2020_artifacts\image_000004_94641d2fd6bf56aa10ae988d360cc61d80c94f258db9f001b32061ce9d3028da.png
# Analyzing image filename: output_md\output_md\CBA - Annual Report 2020_artifacts\image_000005_57bd51748c1bd7b568e6b239a314fbfcbe768bc06f08e4a1af782071a3279684.png
# Analyzing image filename: output_md\output_md\CBA - Annual Report 2020_artifacts\image_000006_c34ca543f0c92f7ecb509893ed1c849ede0e4f71987869270296212139f26569.png
# Analyzing image filename: output_md\output_md\CBA - Annual Report 2020_artifacts\image_000007_559315322c64f5b31928f487847fd9986ecf3066ab05e18fd456e8b67f281913.png
# Analyzing image filename: output_md\output_md\CBA - Annual Report 2020_artifacts\image_000008_d49129144ffef6199ceb7585977b60ffbf3c509161b162ed04d1828e84873027.png
# Analyzing image filename: output_md\output_md\CBA - Annual Report 2020_artifacts\image_000009_71e8bbc9be9a3b53aaeebd7d985024ceb5c3429f69fb34465a954fd2d056d16b.png
# Analyzing image filename: output_md\output_md\CBA - Annual Report 2020_artifacts\image_000010_fa1b8ee1819625b33cee04aabd81faf0aa73ad4c01aaa31c54e5ea1168622a49.png
# Analyzing image filename: output_md\output_md\CBA - Annual Report 2020_artifacts\image_000011_b736562bbe0abeffae08fdf9a92fa13c1e18b63f60d06bd0a8849afdc7d80815.png
# An error occurred: Error analyzing image: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 10, model: gemini-2.5-flash
# Please retry in 55.749416285s. [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 10
# }
# , retry_delay {
#   seconds: 55
# }
# ]
#
# Processing md file: output_md\CBA - Annual Report 2021.md
# Analyzing image filename: output_md\output_md\CBA - Annual Report 2021_artifacts\image_000000_02dc4563da268bbb557b9b20fba15e3ec616d114f7d766fc50ee8d5a29ffbd60.png
# An error occurred: Error analyzing image: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 10, model: gemini-2.5-flash
# Please retry in 55.222243202s. [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 10
# }
# , retry_delay {
#   seconds: 55
# }
# ]
#
# Processing md file: output_md\CBA - Annual Report 2022.md
# Analyzing image filename: output_md\output_md\CBA - Annual Report 2022_artifacts\image_000000_a96a148942f67f4714cd3ee2475fa7de827ac061fae3a0208897139be6fd149c.png
# An error occurred: Error analyzing image: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 10, model: gemini-2.5-flash
# Please retry in 54.82558705s. [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 10
# }
# , retry_delay {
#   seconds: 54
# }
# ]

# %%
# Create ChromaDB vector database with the correct file paths
docling_util.create_chroma_vectordb (file_paths=[
    #"output_md\\CBA - Annual Report 2020.md",
    #"output_md\\CBA - Annual Report 2021.md", 
    "output_md\\CBA - Annual Report 2022.md"
])
# Out:
# 2025-12-09 19:55:22,560 - INFO - detected formats: [<InputFormat.MD: 'md'>]
# 2025-12-09 19:55:22,566 - INFO - Going to convert document batch...
# 2025-12-09 19:55:22,568 - INFO - Initializing pipeline for SimplePipeline with options hash 995a146ad601044538e6a923bea22f4e
# 2025-12-09 19:55:22,633 - INFO - Loading plugin 'docling_defaults'
# 2025-12-09 19:55:22,640 - WARNING - The plugin langchain_docling will not be loaded because Docling is being executed with allow_external_plugins=false.
# 2025-12-09 19:55:22,641 - INFO - Registered picture descriptions: ['vlm', 'api']
# 2025-12-09 19:55:22,642 - INFO - Processing document CBA - Annual Report 2022.md
# 2025-12-09 19:55:29,057 - INFO - Finished converting document CBA - Annual Report 2022.md in 6.51 sec.
# Token indices sequence length is longer than the specified maximum sequence length for this model (1058 > 512). Running this sequence through the model will result in indexing errors
# c:\FYP\IBM FYP RAG\docling_util_baseline.py:263: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(model_name=model_name)
# 2025-12-09 19:55:32,844 - INFO - Use pytorch device_name: cpu
# 2025-12-09 19:55:32,846 - INFO - Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# 2025-12-09 19:55:36,876 - INFO - Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# Vectorstore saved permanently to: c:\FYP\IBM FYP RAG\chroma_db

# %%
# Set IBM Watsonx credentials run 
import os
os.environ["WATSONX_APIKEY"] = "wmYPwxoE3VrEUxHjPoBfQGc9_bWoq2tAlBmwtyfD4byr"
os.environ["IBM_PROJECT_ID"] = "fdeaf360-1c36-44a4-8cd1-1b5183b6ace4"
#using lecturer's project and apikey for testing
#os.environ["WATSONX_URL"] = "https://jp-tok.ml.cloud.ibm.com"  
#os.environ["IBM_PROJECT_ID"] = "2ebb6ffd-00ec-4919-9652-3cf73bc44ab2"
#os.environ["WATSONX_API_KEY"] = "8tm6_669XtiuGkC_lkRv3z78-PJ0QlTlaFqAnsk0xeqj"
print("Environment variables set successfully!")
# Out:
# Environment variables set successfully!

# %% [markdown]
# ## Using Ollama(Local LLM) IBM watsonx out of credits

# %%
import query_util_exp3 as query_util

# This will automatically use phi3:medium because it's the default in exp3.py
qa_chain = query_util.setup_qa_chain(
    local_vector_store_path="./chroma_db",
    #use_ollama=True is already set in query_util_exp3.py
    #ollama_model="gemma3:4b" is already set in query_util_exp3.py
)
# Out:
# c:\FYP\IBM FYP RAG\query_util_exp3.py:86: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(model_name=embbedings_model_name)
# 2026-01-22 00:14:02,696 - INFO - Use pytorch device_name: cpu
# 2026-01-22 00:14:02,697 - INFO - Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# ✓ Using Ollama with model: gemma3:4b
# Loading vector store from local path: ./chroma_db
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 4
#       1 import query_util_exp3 as query_util
#       3 # This will automatically use phi3:medium because it's the default in exp3.py
# ----> 4 qa_chain = query_util.setup_qa_chain(
#       5     local_vector_store_path="./chroma_db",
#       6     #use_ollama=True is already set in query_util_exp3.py
#       7     #ollama_model="gemma3:4b" is already set in query_util_exp3.py
#       8 )
#
# File c:\FYP\IBM FYP RAG\query_util_exp3.py:86, in setup_qa_chain(local_vector_store_path, vector_object, use_local_path, model_id, embbedings_model_name, use_ollama, ollama_model, temperature)
#      84         raise ValueError("`local_vector_store_path` must be provided when `use_local_path` is True.")
#      85     print(f"Loading vector store from local path: {local_vector_store_path}")
# ---> 86     embeddings = HuggingFaceEmbeddings(model_name=embbedings_model_name)
#      87     retriever_source = Chroma(persist_directory=local_vector_store_path,
#      88         embedding_function=embeddings)
#      89 else:
#
# File c:\FYP\IBM FYP RAG\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:239, in deprecated.<locals>.deprecate.<locals>.finalize.<locals>.warn_if_direct_instance(self, *args, **kwargs)
#     237     warned = True
#     238     emit_warning()
# --> 239 return wrapped(self, *args, **kwargs)
#
# File c:\FYP\IBM FYP RAG\.venv\Lib\site-packages\langchain_community\embeddings\huggingface.py:92, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      86 except ImportError as exc:
#      87     raise ImportError(
#      88         "Could not import sentence_transformers python package. "
#      89         "Please install it with `pip install sentence-transformers`."
#      90     ) from exc
# ---> 92 self.client = sentence_transformers.SentenceTransformer(
#      93     self.model_name, cache_folder=self.cache_folder, **self.model_kwargs
#      94 )
#
# File c:\FYP\IBM FYP RAG\.venv\Lib\site-packages\sentence_transformers\SentenceTransformer.py:318, in SentenceTransformer.__init__(self, model_name_or_path, modules, device, prompts, default_prompt_name, similarity_fn_name, cache_folder, trust_remote_code, revision, local_files_only, token, use_auth_token, truncate_dim, model_kwargs, tokenizer_kwargs, config_kwargs, model_card_data, backend)
#     308         model_name_or_path = __MODEL_HUB_ORGANIZATION__ + "/" + model_name_or_path
#     309 has_modules = is_sentence_transformer_model(
#     310     model_name_or_path,
#     311     token,
#    (...)    314     local_files_only=local_files_only,
#     315 )
#     316 if (
#     317     has_modules
# --> 318     and self._get_model_type(
#     319         model_name_or_path,
#     320         token,
#     321         cache_folder=cache_folder,
#     322         revision=revision,
#     323         local_files_only=local_files_only,
#     324     )
#     325     == self._model_config["model_type"]
#     326 ):
#     327     modules, self.module_kwargs = self._load_sbert_model(
#     328         model_name_or_path,
#     329         token=token,
#    (...)    336         config_kwargs=config_kwargs,
#     337     )
#     338 else:
#
# File c:\FYP\IBM FYP RAG\.venv\Lib\site-packages\sentence_transformers\SentenceTransformer.py:2500, in SentenceTransformer._get_model_type(self, model_name_or_path, token, cache_folder, revision, local_files_only)
#    2472 def _get_model_type(
#    2473     self,
#    2474     model_name_or_path: str,
#    (...)   2478     local_files_only: bool = False,
#    2479 ) -> str | None:
#    2480     """
#    2481     Retrieves the model_type from the config_sentence_transformers.json file.
#    2482
#    (...)   2498         Optional[str]: The model type (SentenceTransformer or SparseEncoder) if available, None otherwise.
#    2499     """
# -> 2500     config_sentence_transformers_json_path = load_file_path(
#    2501         model_name_or_path,
#    2502         "config_sentence_transformers.json",
#    2503         token=token,
#    2504         cache_folder=cache_folder,
#    2505         revision=revision,
#    2506         local_files_only=local_files_only,
#    2507     )
#    2509     if config_sentence_transformers_json_path is None:
#    2510         return "SentenceTransformer"
#
# File c:\FYP\IBM FYP RAG\.venv\Lib\site-packages\sentence_transformers\util\file_io.py:96, in load_file_path(model_name_or_path, filename, subfolder, token, cache_folder, revision, local_files_only)
#      94 file_path = Path(subfolder, filename)
#      95 try:
# ---> 96     return hf_hub_download(
#      97         model_name_or_path,
#      98         filename=file_path.name,
#      99         subfolder=file_path.parent.as_posix(),
#     100         revision=revision,
#     101         library_name="sentence-transformers",
#     102         token=token,
#     103         cache_dir=cache_folder,
#     104         local_files_only=local_files_only,
#     105     )
#     106 except Exception:
#     107     return None
#
# File c:\FYP\IBM FYP RAG\.venv\Lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File c:\FYP\IBM FYP RAG\.venv\Lib\site-packages\huggingface_hub\file_download.py:1007, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     987     return _hf_hub_download_to_local_dir(
#     988         # Destination
#     989         local_dir=local_dir,
#    (...)   1004         local_files_only=local_files_only,
#    1005     )
#    1006 else:
# -> 1007     return _hf_hub_download_to_cache_dir(
#    1008         # Destination
#    1009         cache_dir=cache_dir,
#    1010         # File info
#    1011         repo_id=repo_id,
#    1012         filename=filename,
#    1013         repo_type=repo_type,
#    1014         revision=revision,
#    1015         # HTTP info
#    1016         endpoint=endpoint,
#    1017         etag_timeout=etag_timeout,
#    1018         headers=hf_headers,
#    1019         proxies=proxies,
#    1020         token=token,
#    1021         # Additional options
#    1022         local_files_only=local_files_only,
#    1023         force_download=force_download,
#    1024     )
#
# File c:\FYP\IBM FYP RAG\.venv\Lib\site-packages\huggingface_hub\file_download.py:1070, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1066         return pointer_path
#    1068 # Try to get metadata (etag, commit_hash, url, size) from the server.
#    1069 # If we can't, a HEAD request error is returned.
# -> 1070 (url_to_download, etag, commit_hash, expected_size, xet_file_data, head_call_error) = _get_metadata_or_catch_error(
#    1071     repo_id=repo_id,
#    1072     filename=filename,
#    1073     repo_type=repo_type,
#    1074     revision=revision,
#    1075     endpoint=endpoint,
#    1076     proxies=proxies,
#    1077     etag_timeout=etag_timeout,
#    1078     headers=headers,
#    1079     token=token,
#    1080     local_files_only=local_files_only,
#    1081     storage_folder=storage_folder,
#    1082     relative_filename=relative_filename,
#    1083 )
#    1085 # etag can be None for several reasons:
#    1086 # 1. we passed local_files_only.
#    1087 # 2. we don't have a connection
#    (...)   1093 # If the specified revision is a commit hash, look inside "snapshots".
#    1094 # If the specified revision is a branch or tag, look inside "refs".
#    1095 if head_call_error is not None:
#    1096     # Couldn't make a HEAD call => let's try to find a local file
#
# File c:\FYP\IBM FYP RAG\.venv\Lib\site-packages\huggingface_hub\file_download.py:1543, in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, proxies, etag_timeout, headers, token, local_files_only, relative_filename, storage_folder)
#    1541 try:
#    1542     try:
# -> 1543         metadata = get_hf_file_metadata(
#    1544             url=url, proxies=proxies, timeout=etag_timeout, headers=headers, token=token, endpoint=endpoint
#    1545         )
#    1546     except EntryNotFoundError as http_error:
#    1547         if storage_folder is not None and relative_filename is not None:
#    1548             # Cache the non-existence of the file
#
# File c:\FYP\IBM FYP RAG\.venv\Lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File c:\FYP\IBM FYP RAG\.venv\Lib\site-packages\huggingface_hub\file_download.py:1460, in get_hf_file_metadata(url, token, proxies, timeout, library_name, library_version, user_agent, headers, endpoint)
#    1457 hf_headers["Accept-Encoding"] = "identity"  # prevent any compression => we want to know the real size of the file
#    1459 # Retrieve metadata
# -> 1460 r = _request_wrapper(
#    1461     method="HEAD",
#    1462     url=url,
#    1463     headers=hf_headers,
#    1464     allow_redirects=False,
#    1465     follow_relative_redirects=True,
#    1466     proxies=proxies,
#    1467     timeout=timeout,
#    1468 )
#    1469 hf_raise_for_status(r)
#    1471 # Return
#
# File c:\FYP\IBM FYP RAG\.venv\Lib\site-packages\huggingface_hub\file_download.py:283, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     281 # Recursively follow relative redirects
#     282 if follow_relative_redirects:
# --> 283     response = _request_wrapper(
#     284         method=method,
#     285         url=url,
#     286         follow_relative_redirects=False,
#     287         **params,
#     288     )
#     290     # If redirection, we redirect only relative paths.
#     291     # This is useful in case of a renamed repository.
#     292     if 300 <= response.status_code <= 399:
#
# File c:\FYP\IBM FYP RAG\.venv\Lib\site-packages\huggingface_hub\file_download.py:306, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     303     return response
#     305 # Perform request and return if status_code is not in the retry list.
# --> 306 response = http_backoff(method=method, url=url, **params)
#     307 hf_raise_for_status(response)
#     308 return response
#
# File c:\FYP\IBM FYP RAG\.venv\Lib\site-packages\huggingface_hub\utils\_http.py:306, in http_backoff(method, url, max_retries, base_wait_time, max_wait_time, retry_on_exceptions, retry_on_status_codes, **kwargs)
#     303     kwargs["data"].seek(io_obj_initial_pos)
#     305 # Perform request and return if status_code is not in the retry list.
# --> 306 response = session.request(method=method, url=url, **kwargs)
#     307 if response.status_code not in retry_on_status_codes:
#     308     return response
#
# File c:\FYP\IBM FYP RAG\.venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\FYP\IBM FYP RAG\.venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\FYP\IBM FYP RAG\.venv\Lib\site-packages\huggingface_hub\utils\_http.py:95, in UniqueRequestIdAdapter.send(self, request, *args, **kwargs)
#      93     logger.debug(f"Send: {_curlify(request)}")
#      94 try:
# ---> 95     return super().send(request, *args, **kwargs)
#      96 except requests.RequestException as e:
#      97     request_id = request.headers.get(X_AMZN_TRACE_ID)
#
# File c:\FYP\IBM FYP RAG\.venv\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File c:\FYP\IBM FYP RAG\.venv\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\FYP\IBM FYP RAG\.venv\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\FYP\IBM FYP RAG\.venv\Lib\site-packages\urllib3\connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\http\client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import query_util_exp4 as query_util

# This will automatically use phi3:medium because it's the default in exp3.py
qa_chain = query_util.setup_qa_chain(
    local_vector_store_path="./chroma_db",
    use_ollama=True,  # already set in query_util_exp3.py
    ollama_model="llama3.1"  # already set in query_util_exp4.py
)
# Out:
# 2026-01-22 00:17:26,226 - INFO - Use pytorch device_name: cpu
# 2026-01-22 00:17:26,227 - INFO - Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# ✓ Using Ollama with model: llama3.1
# Loading vector store from local path: ./chroma_db
# 2026-01-22 00:17:30,518 - INFO - Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.

# %%
golden_questions = [
    "Who is the Chairman of the Board?",
    "What is the company's mission or vision statement?",
    "What were the key highlights mentioned in the Chairman's statement?",
    "Who are the Board Members and describe their responsibilities",
    "What major strategic priority was announced for the upcoming financial year?"
]

# %%
# Use the correct list name: golden_dataset_questions
for q in golden_questions:
    print(f"Q: {q}")
    
    # Use the variable name 'qa_chain' from your setup cell
    answer = query_util.ask_question(qa_chain, q)
    
    # CHANGE THIS: Use ['answer'] instead of ['result']
    print(f"A: {answer['answer']}")
    print("-" * 30)
# Out:
# Q: Who is the Chairman of the Board?
# c:\FYP\IBM FYP RAG\query_util_exp4.py:136: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain-classic 0.1.0 and will be removed in 1.0. Use `invoke` instead.
#   result = qa_chain({"query": question})

# %%
golden_dataset_questions = [
    # A. Factual Information from Plain Text (10 Questions)
    "Who is the CEO/Managing Director of the company?",
    "What is the company's primary business activity?",
    "In which year was the company incorporated?",
    "Describe markets or regions does the company operate in?",
    "What are the company's three main business segments?",
    "Who is the Chairman of the Board?",
    "What is the company's mission or vision statement?",
    "What were the key highlights mentioned in the Chairman's statement?",
    "Who are the Board Members and describe their responsibilities",
    "What major strategic priority was announced for the upcoming financial year?",
    
    # B. Factual Information from Tables (10 Questions)
    "What is the total revenue for FY2023?",
    "What is the net profit after tax for FY2023?",
    "What is the Earnings Per Share (EPS) for FY2023?",
    "What is the Total Assets value for FY2023?",
    "What is the Total Equity attributable to shareholders?",
    "What is the Net Asset Value (NAV) per share?",
    "What is the debt-to-equity ratio listed in the Key Financial Ratios table?",
    "Which business segment contributed the highest revenue?",
    "What is the percentage increase/decrease in revenue compared to FY2022?",
    "What is the total dividend declared for the reporting year?",
    
    # C. Interpretation of Charts (5 Questions)
    "According to the revenue trend chart, which year recorded the highest revenue?",
    "Based on the profit margin chart, what is the approximate net profit margin for FY2023?",
    "From the segment revenue bar chart, which segment experienced the largest year-on-year growth?",
    "According to the geographical sales pie chart, which region contributes the largest share?",
    "Based on the cost breakdown chart, which cost category increased the most year-on-year?",
    
    # D. One-Section Summaries (5 Questions)
    "Summarise the main points from the CEO's message in three sentences.",
    "Summarise the company's sustainability/ESG commitments for the reporting year.",
    "What key risks are highlighted in the Risk Management section?",
    "Summarise the business strategy outlined for the next 2–3 years.",
    "What operational achievements are described in the Operations Review section?",
]

# %%
# Use the correct list name: golden_dataset_questions
for q in golden_dataset_questions:
    print(f"Q: {q}")
    
    # Use the variable name 'qa_chain' from your setup cell
    answer = query_util.ask_question(qa_chain, q)
    
    # CHANGE THIS: Use ['answer'] instead of ['result']
    print(f"A: {answer['answer']}")
    print("-" * 30)
# Out:
# Q: Who is the CEO/Managing Director of the company?
# 2026-01-19 01:48:16,027 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# A: Mr Kevin Koo is the CEO/Managing Director of the company.
# ------------------------------
# Q: What is the company's primary business activity?
# 2026-01-19 01:49:02,072 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# A: The company’s primary business activity is providing services for customers’ various purposes including financial health checks, sales and marketing solutions, leads generation, monitoring services, internal compliance, employee screenings, and know-your-customer due diligence. It also operates in the Non-FI Data Business, providing business information and risk management services to enterprise customers.
# ------------------------------
# Q: In which year was the company incorporated?
# 2026-01-19 01:49:57,965 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# A: The Company was incorporated in Singapore with Registration No. 201909251G.
# ------------------------------
# Q: Describe markets or regions does the company operate in?
# 2026-01-19 01:50:32,674 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# A: The company operates in Singapore, Malaysia, Cambodia, and Myanmar. It is also actively exploring opportunities to expand to other territories in the ASEAN region and beyond.
# ------------------------------
# Q: What are the company's three main business segments?
# 2026-01-19 01:51:12,290 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# A: - Non-financial institution data
# - Financial institution data
# ------------------------------
# Q: Who is the Chairman of the Board?
# 2026-01-19 01:52:03,674 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# A: Mr Kevin Koo is the Chairman of the Board.
# ------------------------------
# Q: What is the company's mission or vision statement?
# 2026-01-19 01:52:36,945 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# A: The company’s mission statement is: “To be the key enabler between lenders and borrowers, promoting lending and borrowing, with higher levels of information transparency, greater credit responsibility, and better data security and protection.”
#
# The company’s vision statement is: “We aspire to be the leading credit and risk information solutions provider in the regions we operate in.”
# ------------------------------
# Q: What were the key highlights mentioned in the Chairman's statement?
# 2026-01-19 01:53:40,643 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# A: The key highlights mentioned in the Chairman’s statement are:
#
# *   The quality of information disseminated to members of the Board and Board Committees was adequate to make informed decisions.
# *   The Board and Management had a cordial relationship that encouraged open communication, constructive discussion and independent decision-making.
# *   The Board demonstrated responsiveness and pro-activeness.
# *   There was a high standard of conduct and the Board members proactively disclosed any potential conflict of interest.
# *   The Board and Board Committee meetings were well-conducted and sufficient time was allocated to consider all matters, and the decision-making process took into account all aspects including key issue and relevant stakeholders' concerns.
# *   The Board comprised competent Directors with diverse and relevant experience and expertise.
# ------------------------------
# Q: Who are the Board Members and describe their responsibilities
# 2026-01-19 01:54:46,346 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# A: Based on the provided documents, the Board Members include:
#
# *   **Directors:** The Board of Directors comprises Directors who are expected to provide an appropriate balance and diversity of skills, expertise, gender, and knowledge to the Group. They also have core competencies like accounting, finance, business experience, industry knowledge, strategic planning, and customer-based experience.
# *   **Chairperson of each Board Committee:** Provides updates on significant matters discussed at the Board Committee meetings.
# *   **CEO and/or relevant Management:** Provide updates on the Group’s business and operations.
# *   **CFO:** Presents the Group’s financial performance and related presentations.
# *   **Executive Directors and Management:** Day-to-day management and implementation of business strategies are delegated to them.
#
# **Responsibilities:**
#
# The Board’s responsibilities include:
#
# *   Overseeing the management of the Group’s operations.
# *   Reviewing strategies, policies, and financial performance.
# *   Assessing key risks.
# *   Ensuring the adequacy of internal controls and risk management systems.
# *   Acting in good faith and objectively in the best interests of the Company.
# *   Leading and overseeing the Company, establishing appropriate culture, values, and ethical standards.
#
# I cannot find this information in the provided documents.
# ------------------------------
# Q: What major strategic priority was announced for the upcoming financial year?
# 2026-01-19 01:55:46,412 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# A: I cannot find this information in the provided documents.
# ------------------------------
# Q: What is the total revenue for FY2023?
# 2026-01-19 01:56:22,042 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# A: I cannot find this information in the provided documents.
# ------------------------------
# Q: What is the net profit after tax for FY2023?
# 2026-01-19 01:56:32,014 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# A: I cannot find this information in the provided documents.
# ------------------------------
# Q: What is the Earnings Per Share (EPS) for FY2023?
# 2026-01-19 01:57:29,156 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# A: I cannot find this information in the provided documents.
# ------------------------------
# Q: What is the Total Assets value for FY2023?
# 2026-01-19 01:58:28,805 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# A: I cannot find this information in the provided documents.
# ------------------------------
# Q: What is the Total Equity attributable to shareholders?
# 2026-01-19 01:59:28,879 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# A: I cannot find this information in the provided documents.
# ------------------------------
# Q: What is the Net Asset Value (NAV) per share?
# 2026-01-19 02:00:26,779 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# A: I cannot find the answer to the question "What is the Net Asset Value (NAV) per share?" in the provided documents. The document contains information about net assets for various joint ventures, but it does not calculate or provide the NAV per share.
# ------------------------------
# Q: What is the debt-to-equity ratio listed in the Key Financial Ratios table?
# 2026-01-19 02:01:17,550 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# A: I cannot find this information in the provided documents.
# ------------------------------
# Q: Which business segment contributed the highest revenue?
# 2026-01-19 02:01:55,330 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# A: I cannot find this information in the provided documents.
# ------------------------------
# Q: What is the percentage increase/decrease in revenue compared to FY2022?
# 2026-01-19 02:02:41,425 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# A: I cannot find this information in the provided documents.
# ------------------------------
# Q: What is the total dividend declared for the reporting year?
# 2026-01-19 02:03:55,374 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# A: The total dividend declared for the reporting year is $3,916,630. This includes the final dividend of 1.7 cents per share paid on 3 June 2022 and the interim dividend of 1.7 cents per share paid on 2 September 2022, as well as the proposed final dividend of 1.7 cents per share.
# ------------------------------
# Q: According to the revenue trend chart, which year recorded the highest revenue?
# 2026-01-19 02:05:03,529 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# A: I cannot find this information in the provided documents.
# ------------------------------
# Q: Based on the profit margin chart, what is the approximate net profit margin for FY2023?
# 2026-01-19 02:05:54,407 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# A: I cannot find this information in the provided documents.
# ------------------------------
# Q: From the segment revenue bar chart, which segment experienced the largest year-on-year growth?
# 2026-01-19 02:06:53,243 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# A: I cannot find this information in the provided documents.
# ------------------------------
# Q: According to the geographical sales pie chart, which region contributes the largest share?
# 2026-01-19 02:07:33,657 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# A: I cannot find this information in the provided documents. The text describes the Group’s geographical areas of operation but does not provide any data on sales contributions or a sales pie chart.
# ------------------------------
# Q: Based on the cost breakdown chart, which cost category increased the most year-on-year?
# 2026-01-19 02:08:32,205 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# A: I cannot find this information in the provided documents.
# ------------------------------
# Q: Summarise the main points from the CEO's message in three sentences.
# 2026-01-19 02:09:32,134 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# A: Mr. Kevin Koo expresses his sincere thanks to the management team, fellow directors, business partners, customers, shareholders, and employees for their support and confidence. He acknowledges their leadership, guidance, hard work, and sacrifices as the company continues to grow. Finally, he conveys his appreciation for their unwavering support as the company strives for greater heights in the future.
# ------------------------------
# Q: Summarise the company's sustainability/ESG commitments for the reporting year.
# 2026-01-19 02:10:30,542 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# A: Based on the provided documents, Credit Bureau Asia Limited (CBA) has the following sustainability/ESG commitments for the reporting year (FY2022):
#
# *   **GRI Standards:** They utilized the GRI Standards ‘Core’ option for their reporting.
# *   **EESG Factors:** They incorporated economic, environmental, social, and governance ('EESG') factors into their operations and business growth.
# *   **Sustainability Steering Committee:** They have a Sustainability Steering Committee (SSC) to identify and monitor material EESG factors.
# *   **Annual Review:** The Board validates the materiality assessment and the list of material EESG factors is reviewed annually.
# *   **Stakeholder Engagement:** They will monitor these key EESG matters and update them based on feedback from stakeholders.
#
# **Notably, the company does not currently consider “environment” as a material EESG factor due to its operations and classification.**
# ------------------------------
# Q: What key risks are highlighted in the Risk Management section?
# 2026-01-19 02:11:29,038 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# A: Market risk (including foreign exchange risk, interest rate risk), credit risk, and liquidity risk.
# ------------------------------
# Q: Summarise the business strategy outlined for the next 2–3 years.
# 2026-01-19 02:12:20,700 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# A: I cannot find this information in the provided documents. The document focuses on the company’s economic performance, business model, and operational overview, but does not outline a specific business strategy for the next 2-3 years.
# ------------------------------
# Q: What operational achievements are described in the Operations Review section?
# 2026-01-19 02:13:25,647 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# A: The Operations Review section describes the Group’s assistance to its customers to make better-informed, timely decisions by enhancing their risk assessment and decision-making processes. It includes products and services such as credit and risk information reports, credit scores, monitoring services, data trends and analytics, and client-specific tailored solutions.
# ------------------------------
